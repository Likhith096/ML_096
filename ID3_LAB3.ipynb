# %% [markdown]
# <a href="https://colab.research.google.com/github/Jyothika083/ML/blob/main/ID3_LAB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import math
# Reading the dataset (Tennis-dataset)
data = pd.read_csv('PlayTennis.csv')

# %%
data.head()
# Out:
#     outlook  temp humidity  windy play
# 0     sunny   hot     high  False   no
# 1     sunny   hot     high   True   no
# 2  overcast   hot     high  False  yes
# 3     rainy  mild     high  False  yes
# 4     rainy  cool   normal  False  yes

# %%
def highlight(cell_value):
    '''
    Highlight yes / no values in the dataframe
    '''
    color_1 = 'background-color: pink;'
    color_2 = 'background-color: lightgreen;'

    if cell_value == 'no':
        return color_1
    elif cell_value == 'yes':
        return color_2

data.style.applymap(highlight)\
    .set_properties(subset=data.columns, **{'width': '100px'})\
    .set_table_styles([{'selector': 'th', 'props': [('background-color', 'lightgray'), ('border', '1px solid gray'),
                                                    ('font-weight', 'bold')]},
     {'selector': 'tr:hover', 'props': [('background-color', 'white'), ('border', '1.5px solid black')]}])
# Out:
# <style type="text/css">
# #T_2e01f th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_2e01f tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_2e01f_row0_col0, #T_2e01f_row0_col1, #T_2e01f_row0_col2, #T_2e01f_row0_col3, #T_2e01f_row1_col0, #T_2e01f_row1_col1, #T_2e01f_row1_col2, #T_2e01f_row1_col3, #T_2e01f_row2_col0, #T_2e01f_row2_col1, #T_2e01f_row2_col2, #T_2e01f_row2_col3, #T_2e01f_row3_col0, #T_2e01f_row3_col1, #T_2e01f_row3_col2, #T_2e01f_row3_col3, #T_2e01f_row4_col0, #T_2e01f_row4_col1, #T_2e01f_row4_col2, #T_2e01f_row4_col3, #T_2e01f_row5_col0, #T_2e01f_row5_col1, #T_2e01f_row5_col2, #T_2e01f_row5_col3, #T_2e01f_row6_col0, #T_2e01f_row6_col1, #T_2e01f_row6_col2, #T_2e01f_row6_col3, #T_2e01f_row7_col0, #T_2e01f_row7_col1, #T_2e01f_row7_col2, #T_2e01f_row7_col3, #T_2e01f_row8_col0, #T_2e01f_row8_col1, #T_2e01f_row8_col2, #T_2e01f_row8_col3, #T_2e01f_row9_col0, #T_2e01f_row9_col1, #T_2e01f_row9_col2, #T_2e01f_row9_col3, #T_2e01f_row10_col0, #T_2e01f_row10_col1, #T_2e01f_row10_col2, #T_2e01f_row10_col3, #T_2e01f_row11_col0, #T_2e01f_row11_col1, #T_2e01f_row11_col2, #T_2e01f_row11_col3, #T_2e01f_row12_col0, #T_2e01f_row12_col1, #T_2e01f_row12_col2, #T_2e01f_row12_col3, #T_2e01f_row13_col0, #T_2e01f_row13_col1, #T_2e01f_row13_col2, #T_2e01f_row13_col3 {
#   width: 100px;
# }
# #T_2e01f_row0_col4, #T_2e01f_row1_col4, #T_2e01f_row5_col4, #T_2e01f_row7_col4, #T_2e01f_row13_col4 {
#   background-color: pink;
#   width: 100px;
# }
# #T_2e01f_row2_col4, #T_2e01f_row3_col4, #T_2e01f_row4_col4, #T_2e01f_row6_col4, #T_2e01f_row8_col4, #T_2e01f_row9_col4, #T_2e01f_row10_col4, #T_2e01f_row11_col4, #T_2e01f_row12_col4 {
#   background-color: lightgreen;
#   width: 100px;
# }
# </style>
# <table id="T_2e01f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e01f_level0_col0" class="col_heading level0 col0" >outlook</th>
#       <th id="T_2e01f_level0_col1" class="col_heading level0 col1" >temp</th>
#       <th id="T_2e01f_level0_col2" class="col_heading level0 col2" >humidity</th>
#       <th id="T_2e01f_level0_col3" class="col_heading level0 col3" >windy</th>
#       <th id="T_2e01f_level0_col4" class="col_heading level0 col4" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e01f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e01f_row0_col0" class="data row0 col0" >sunny</td>
#       <td id="T_2e01f_row0_col1" class="data row0 col1" >hot</td>
#       <td id="T_2e01f_row0_col2" class="data row0 col2" >high</td>
#       <td id="T_2e01f_row0_col3" class="data row0 col3" >False</td>
#       <td id="T_2e01f_row0_col4" class="data row0 col4" >no</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e01f_row1_col0" class="data row1 col0" >sunny</td>
#       <td id="T_2e01f_row1_col1" class="data row1 col1" >hot</td>
#       <td id="T_2e01f_row1_col2" class="data row1 col2" >high</td>
#       <td id="T_2e01f_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_2e01f_row1_col4" class="data row1 col4" >no</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e01f_row2_col0" class="data row2 col0" >overcast</td>
#       <td id="T_2e01f_row2_col1" class="data row2 col1" >hot</td>
#       <td id="T_2e01f_row2_col2" class="data row2 col2" >high</td>
#       <td id="T_2e01f_row2_col3" class="data row2 col3" >False</td>
#       <td id="T_2e01f_row2_col4" class="data row2 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2e01f_row3_col0" class="data row3 col0" >rainy</td>
#       <td id="T_2e01f_row3_col1" class="data row3 col1" >mild</td>
#       <td id="T_2e01f_row3_col2" class="data row3 col2" >high</td>
#       <td id="T_2e01f_row3_col3" class="data row3 col3" >False</td>
#       <td id="T_2e01f_row3_col4" class="data row3 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2e01f_row4_col0" class="data row4 col0" >rainy</td>
#       <td id="T_2e01f_row4_col1" class="data row4 col1" >cool</td>
#       <td id="T_2e01f_row4_col2" class="data row4 col2" >normal</td>
#       <td id="T_2e01f_row4_col3" class="data row4 col3" >False</td>
#       <td id="T_2e01f_row4_col4" class="data row4 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2e01f_row5_col0" class="data row5 col0" >rainy</td>
#       <td id="T_2e01f_row5_col1" class="data row5 col1" >cool</td>
#       <td id="T_2e01f_row5_col2" class="data row5 col2" >normal</td>
#       <td id="T_2e01f_row5_col3" class="data row5 col3" >True</td>
#       <td id="T_2e01f_row5_col4" class="data row5 col4" >no</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2e01f_row6_col0" class="data row6 col0" >overcast</td>
#       <td id="T_2e01f_row6_col1" class="data row6 col1" >cool</td>
#       <td id="T_2e01f_row6_col2" class="data row6 col2" >normal</td>
#       <td id="T_2e01f_row6_col3" class="data row6 col3" >True</td>
#       <td id="T_2e01f_row6_col4" class="data row6 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2e01f_row7_col0" class="data row7 col0" >sunny</td>
#       <td id="T_2e01f_row7_col1" class="data row7 col1" >mild</td>
#       <td id="T_2e01f_row7_col2" class="data row7 col2" >high</td>
#       <td id="T_2e01f_row7_col3" class="data row7 col3" >False</td>
#       <td id="T_2e01f_row7_col4" class="data row7 col4" >no</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2e01f_row8_col0" class="data row8 col0" >sunny</td>
#       <td id="T_2e01f_row8_col1" class="data row8 col1" >cool</td>
#       <td id="T_2e01f_row8_col2" class="data row8 col2" >normal</td>
#       <td id="T_2e01f_row8_col3" class="data row8 col3" >False</td>
#       <td id="T_2e01f_row8_col4" class="data row8 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2e01f_row9_col0" class="data row9 col0" >rainy</td>
#       <td id="T_2e01f_row9_col1" class="data row9 col1" >mild</td>
#       <td id="T_2e01f_row9_col2" class="data row9 col2" >normal</td>
#       <td id="T_2e01f_row9_col3" class="data row9 col3" >False</td>
#       <td id="T_2e01f_row9_col4" class="data row9 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2e01f_row10_col0" class="data row10 col0" >sunny</td>
#       <td id="T_2e01f_row10_col1" class="data row10 col1" >mild</td>
#       <td id="T_2e01f_row10_col2" class="data row10 col2" >normal</td>
#       <td id="T_2e01f_row10_col3" class="data row10 col3" >True</td>
#       <td id="T_2e01f_row10_col4" class="data row10 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2e01f_row11_col0" class="data row11 col0" >overcast</td>
#       <td id="T_2e01f_row11_col1" class="data row11 col1" >mild</td>
#       <td id="T_2e01f_row11_col2" class="data row11 col2" >high</td>
#       <td id="T_2e01f_row11_col3" class="data row11 col3" >True</td>
#       <td id="T_2e01f_row11_col4" class="data row11 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2e01f_row12_col0" class="data row12 col0" >overcast</td>
#       <td id="T_2e01f_row12_col1" class="data row12 col1" >hot</td>
#       <td id="T_2e01f_row12_col2" class="data row12 col2" >normal</td>
#       <td id="T_2e01f_row12_col3" class="data row12 col3" >False</td>
#       <td id="T_2e01f_row12_col4" class="data row12 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_2e01f_level0_row13" class="row_heading level0 row13" >13</th>

# %%
def find_entropy(data):
    """
    Returns the entropy of the class or features
    formula: - ∑ P(X)logP(X)
    """
    entropy = 0
    for i in range(data.nunique()):
        x = data.value_counts()[i]/data.shape[0]
        entropy += (- x * math.log(x,2))
    return round(entropy,3)
def information_gain(data, data_):
    """
    Returns the information gain of the features
    """
    info = 0
    for i in range(data_.nunique()):
        df = data[data_ == data_.unique()[i]]
        w_avg = df.shape[0]/data.shape[0]
        entropy = find_entropy(df.play)
        x = w_avg * entropy
        info += x
    ig = find_entropy(data.play) - info
    return round(ig, 3)
def entropy_and_infogain(datax, feature):
    """
    Grouping features with the same class and computing their
    entropy and information gain for splitting
    """
    for i in range(data[feature].nunique()):
        df = datax[datax[feature]==data[feature].unique()[i]]
        if df.shape[0] < 1:
            continue

        display(df[[feature, 'play']].style.applymap(highlight)\
                .set_properties(subset=[feature, 'play'], **{'width': '80px'})\
                .set_table_styles([{'selector': 'th', 'props': [('background-color', 'lightgray'),
                                                                ('border', '1px solid gray'),
                                                                ('font-weight', 'bold')]},
                                   {'selector': 'td', 'props': [('border', '1px solid gray')]},
                                   {'selector': 'tr:hover', 'props': [('background-color', 'white'),
                                                                      ('border', '1.5px solid black')]}]))

        print(f'Entropy of {feature} - {data[feature].unique()[i]} = {find_entropy(df.play)}')
    print(f'Information Gain for {feature} = {information_gain(datax, datax[feature])}')

# %%
print(f'Entropy of the entire dataset: {find_entropy(data.play)}')
# Out:
# Entropy of the entire dataset: 0.94

# %%
entropy_and_infogain(data, 'outlook')
# Out:
# <style type="text/css">
# #T_bdd46 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_bdd46 td {
#   border: 1px solid gray;
# }
# #T_bdd46 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_bdd46_row0_col0, #T_bdd46_row1_col0, #T_bdd46_row2_col0, #T_bdd46_row3_col0, #T_bdd46_row4_col0 {
#   width: 80px;
# }
# #T_bdd46_row0_col1, #T_bdd46_row1_col1, #T_bdd46_row2_col1 {
#   background-color: pink;
#   width: 80px;
# }
# #T_bdd46_row3_col1, #T_bdd46_row4_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# </style>
# <table id="T_bdd46" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdd46_level0_col0" class="col_heading level0 col0" >outlook</th>
#       <th id="T_bdd46_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdd46_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdd46_row0_col0" class="data row0 col0" >sunny</td>
#       <td id="T_bdd46_row0_col1" class="data row0 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_bdd46_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bdd46_row1_col0" class="data row1 col0" >sunny</td>
#       <td id="T_bdd46_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_bdd46_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_bdd46_row2_col0" class="data row2 col0" >sunny</td>
#       <td id="T_bdd46_row2_col1" class="data row2 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_bdd46_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_bdd46_row3_col0" class="data row3 col0" >sunny</td>
#       <td id="T_bdd46_row3_col1" class="data row3 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_bdd46_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_bdd46_row4_col0" class="data row4 col0" >sunny</td>
#       <td id="T_bdd46_row4_col1" class="data row4 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of outlook - sunny = 0.971
# <style type="text/css">
# #T_976bd th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_976bd td {
#   border: 1px solid gray;
# }
# #T_976bd tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_976bd_row0_col0, #T_976bd_row1_col0, #T_976bd_row2_col0, #T_976bd_row3_col0 {
#   width: 80px;
# }
# #T_976bd_row0_col1, #T_976bd_row1_col1, #T_976bd_row2_col1, #T_976bd_row3_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# </style>
# <table id="T_976bd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_976bd_level0_col0" class="col_heading level0 col0" >outlook</th>
#       <th id="T_976bd_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_976bd_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_976bd_row0_col0" class="data row0 col0" >overcast</td>
#       <td id="T_976bd_row0_col1" class="data row0 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_976bd_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_976bd_row1_col0" class="data row1 col0" >overcast</td>
#       <td id="T_976bd_row1_col1" class="data row1 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_976bd_level0_row2" class="row_heading level0 row2" >11</th>
#       <td id="T_976bd_row2_col0" class="data row2 col0" >overcast</td>
#       <td id="T_976bd_row2_col1" class="data row2 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_976bd_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_976bd_row3_col0" class="data row3 col0" >overcast</td>
#       <td id="T_976bd_row3_col1" class="data row3 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of outlook - overcast = 0.0
# <style type="text/css">
# #T_592a2 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_592a2 td {
#   border: 1px solid gray;
# }
# #T_592a2 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_592a2_row0_col0, #T_592a2_row1_col0, #T_592a2_row2_col0, #T_592a2_row3_col0, #T_592a2_row4_col0 {
#   width: 80px;
# }
# #T_592a2_row0_col1, #T_592a2_row1_col1, #T_592a2_row3_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# #T_592a2_row2_col1, #T_592a2_row4_col1 {
#   background-color: pink;
#   width: 80px;
# }
# </style>
# <table id="T_592a2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_592a2_level0_col0" class="col_heading level0 col0" >outlook</th>
#       <th id="T_592a2_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_592a2_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_592a2_row0_col0" class="data row0 col0" >rainy</td>
#       <td id="T_592a2_row0_col1" class="data row0 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_592a2_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_592a2_row1_col0" class="data row1 col0" >rainy</td>
#       <td id="T_592a2_row1_col1" class="data row1 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_592a2_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_592a2_row2_col0" class="data row2 col0" >rainy</td>
#       <td id="T_592a2_row2_col1" class="data row2 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_592a2_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_592a2_row3_col0" class="data row3 col0" >rainy</td>
#       <td id="T_592a2_row3_col1" class="data row3 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_592a2_level0_row4" class="row_heading level0 row4" >13</th>
#       <td id="T_592a2_row4_col0" class="data row4 col0" >rainy</td>
#       <td id="T_592a2_row4_col1" class="data row4 col1" >no</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of outlook - rainy = 0.971
# Information Gain for outlook = 0.246

# %%
entropy_and_infogain(data, 'temp')
# Out:
# <style type="text/css">
# #T_a42c3 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_a42c3 td {
#   border: 1px solid gray;
# }
# #T_a42c3 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_a42c3_row0_col0, #T_a42c3_row1_col0, #T_a42c3_row2_col0, #T_a42c3_row3_col0 {
#   width: 80px;
# }
# #T_a42c3_row0_col1, #T_a42c3_row1_col1 {
#   background-color: pink;
#   width: 80px;
# }
# #T_a42c3_row2_col1, #T_a42c3_row3_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# </style>
# <table id="T_a42c3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a42c3_level0_col0" class="col_heading level0 col0" >temp</th>
#       <th id="T_a42c3_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a42c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a42c3_row0_col0" class="data row0 col0" >hot</td>
#       <td id="T_a42c3_row0_col1" class="data row0 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_a42c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a42c3_row1_col0" class="data row1 col0" >hot</td>
#       <td id="T_a42c3_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_a42c3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a42c3_row2_col0" class="data row2 col0" >hot</td>
#       <td id="T_a42c3_row2_col1" class="data row2 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_a42c3_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_a42c3_row3_col0" class="data row3 col0" >hot</td>
#       <td id="T_a42c3_row3_col1" class="data row3 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of temp - hot = 1.0
# <style type="text/css">
# #T_30f02 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_30f02 td {
#   border: 1px solid gray;
# }
# #T_30f02 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_30f02_row0_col0, #T_30f02_row1_col0, #T_30f02_row2_col0, #T_30f02_row3_col0, #T_30f02_row4_col0, #T_30f02_row5_col0 {
#   width: 80px;
# }
# #T_30f02_row0_col1, #T_30f02_row2_col1, #T_30f02_row3_col1, #T_30f02_row4_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# #T_30f02_row1_col1, #T_30f02_row5_col1 {
#   background-color: pink;
#   width: 80px;
# }
# </style>
# <table id="T_30f02" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30f02_level0_col0" class="col_heading level0 col0" >temp</th>
#       <th id="T_30f02_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30f02_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_30f02_row0_col0" class="data row0 col0" >mild</td>
#       <td id="T_30f02_row0_col1" class="data row0 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_30f02_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_30f02_row1_col0" class="data row1 col0" >mild</td>
#       <td id="T_30f02_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_30f02_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_30f02_row2_col0" class="data row2 col0" >mild</td>
#       <td id="T_30f02_row2_col1" class="data row2 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_30f02_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_30f02_row3_col0" class="data row3 col0" >mild</td>
#       <td id="T_30f02_row3_col1" class="data row3 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_30f02_level0_row4" class="row_heading level0 row4" >11</th>
#       <td id="T_30f02_row4_col0" class="data row4 col0" >mild</td>
#       <td id="T_30f02_row4_col1" class="data row4 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_30f02_level0_row5" class="row_heading level0 row5" >13</th>
#       <td id="T_30f02_row5_col0" class="data row5 col0" >mild</td>
#       <td id="T_30f02_row5_col1" class="data row5 col1" >no</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of temp - mild = 0.918
# <style type="text/css">
# #T_713b4 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_713b4 td {
#   border: 1px solid gray;
# }
# #T_713b4 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_713b4_row0_col0, #T_713b4_row1_col0, #T_713b4_row2_col0, #T_713b4_row3_col0 {
#   width: 80px;
# }
# #T_713b4_row0_col1, #T_713b4_row2_col1, #T_713b4_row3_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# #T_713b4_row1_col1 {
#   background-color: pink;
#   width: 80px;
# }
# </style>
# <table id="T_713b4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_713b4_level0_col0" class="col_heading level0 col0" >temp</th>
#       <th id="T_713b4_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_713b4_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_713b4_row0_col0" class="data row0 col0" >cool</td>
#       <td id="T_713b4_row0_col1" class="data row0 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_713b4_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_713b4_row1_col0" class="data row1 col0" >cool</td>
#       <td id="T_713b4_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_713b4_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_713b4_row2_col0" class="data row2 col0" >cool</td>
#       <td id="T_713b4_row2_col1" class="data row2 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_713b4_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_713b4_row3_col0" class="data row3 col0" >cool</td>
#       <td id="T_713b4_row3_col1" class="data row3 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of temp - cool = 0.811
# Information Gain for temp = 0.029

# %%
entropy_and_infogain(data, 'humidity')
# Out:
# <style type="text/css">
# #T_7c35b th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_7c35b td {
#   border: 1px solid gray;
# }
# #T_7c35b tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_7c35b_row0_col0, #T_7c35b_row1_col0, #T_7c35b_row2_col0, #T_7c35b_row3_col0, #T_7c35b_row4_col0, #T_7c35b_row5_col0, #T_7c35b_row6_col0 {
#   width: 80px;
# }
# #T_7c35b_row0_col1, #T_7c35b_row1_col1, #T_7c35b_row4_col1, #T_7c35b_row6_col1 {
#   background-color: pink;
#   width: 80px;
# }
# #T_7c35b_row2_col1, #T_7c35b_row3_col1, #T_7c35b_row5_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# </style>
# <table id="T_7c35b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c35b_level0_col0" class="col_heading level0 col0" >humidity</th>
#       <th id="T_7c35b_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c35b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c35b_row0_col0" class="data row0 col0" >high</td>
#       <td id="T_7c35b_row0_col1" class="data row0 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_7c35b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c35b_row1_col0" class="data row1 col0" >high</td>
#       <td id="T_7c35b_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_7c35b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c35b_row2_col0" class="data row2 col0" >high</td>
#       <td id="T_7c35b_row2_col1" class="data row2 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_7c35b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c35b_row3_col0" class="data row3 col0" >high</td>
#       <td id="T_7c35b_row3_col1" class="data row3 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_7c35b_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_7c35b_row4_col0" class="data row4 col0" >high</td>
#       <td id="T_7c35b_row4_col1" class="data row4 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_7c35b_level0_row5" class="row_heading level0 row5" >11</th>
#       <td id="T_7c35b_row5_col0" class="data row5 col0" >high</td>
#       <td id="T_7c35b_row5_col1" class="data row5 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_7c35b_level0_row6" class="row_heading level0 row6" >13</th>
#       <td id="T_7c35b_row6_col0" class="data row6 col0" >high</td>
#       <td id="T_7c35b_row6_col1" class="data row6 col1" >no</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of humidity - high = 0.985
# <style type="text/css">
# #T_973af th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_973af td {
#   border: 1px solid gray;
# }
# #T_973af tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_973af_row0_col0, #T_973af_row1_col0, #T_973af_row2_col0, #T_973af_row3_col0, #T_973af_row4_col0, #T_973af_row5_col0, #T_973af_row6_col0 {
#   width: 80px;
# }
# #T_973af_row0_col1, #T_973af_row2_col1, #T_973af_row3_col1, #T_973af_row4_col1, #T_973af_row5_col1, #T_973af_row6_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# #T_973af_row1_col1 {
#   background-color: pink;
#   width: 80px;
# }
# </style>
# <table id="T_973af" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_973af_level0_col0" class="col_heading level0 col0" >humidity</th>
#       <th id="T_973af_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_973af_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_973af_row0_col0" class="data row0 col0" >normal</td>
#       <td id="T_973af_row0_col1" class="data row0 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_973af_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_973af_row1_col0" class="data row1 col0" >normal</td>
#       <td id="T_973af_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_973af_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_973af_row2_col0" class="data row2 col0" >normal</td>
#       <td id="T_973af_row2_col1" class="data row2 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_973af_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_973af_row3_col0" class="data row3 col0" >normal</td>
#       <td id="T_973af_row3_col1" class="data row3 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_973af_level0_row4" class="row_heading level0 row4" >9</th>
#       <td id="T_973af_row4_col0" class="data row4 col0" >normal</td>
#       <td id="T_973af_row4_col1" class="data row4 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_973af_level0_row5" class="row_heading level0 row5" >10</th>
#       <td id="T_973af_row5_col0" class="data row5 col0" >normal</td>
#       <td id="T_973af_row5_col1" class="data row5 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_973af_level0_row6" class="row_heading level0 row6" >12</th>
#       <td id="T_973af_row6_col0" class="data row6 col0" >normal</td>
#       <td id="T_973af_row6_col1" class="data row6 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of humidity - normal = 0.592
# Information Gain for humidity = 0.151

# %%
entropy_and_infogain(data, 'windy')
# Out:
# <style type="text/css">
# #T_773b5 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_773b5 td {
#   border: 1px solid gray;
# }
# #T_773b5 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_773b5_row0_col0, #T_773b5_row1_col0, #T_773b5_row2_col0, #T_773b5_row3_col0, #T_773b5_row4_col0, #T_773b5_row5_col0, #T_773b5_row6_col0, #T_773b5_row7_col0 {
#   width: 80px;
# }
# #T_773b5_row0_col1, #T_773b5_row4_col1 {
#   background-color: pink;
#   width: 80px;
# }
# #T_773b5_row1_col1, #T_773b5_row2_col1, #T_773b5_row3_col1, #T_773b5_row5_col1, #T_773b5_row6_col1, #T_773b5_row7_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# </style>
# <table id="T_773b5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_773b5_level0_col0" class="col_heading level0 col0" >windy</th>
#       <th id="T_773b5_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_773b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_773b5_row0_col0" class="data row0 col0" >False</td>
#       <td id="T_773b5_row0_col1" class="data row0 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_773b5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_773b5_row1_col0" class="data row1 col0" >False</td>
#       <td id="T_773b5_row1_col1" class="data row1 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_773b5_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_773b5_row2_col0" class="data row2 col0" >False</td>
#       <td id="T_773b5_row2_col1" class="data row2 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_773b5_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_773b5_row3_col0" class="data row3 col0" >False</td>
#       <td id="T_773b5_row3_col1" class="data row3 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_773b5_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_773b5_row4_col0" class="data row4 col0" >False</td>
#       <td id="T_773b5_row4_col1" class="data row4 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_773b5_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_773b5_row5_col0" class="data row5 col0" >False</td>
#       <td id="T_773b5_row5_col1" class="data row5 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_773b5_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_773b5_row6_col0" class="data row6 col0" >False</td>
#       <td id="T_773b5_row6_col1" class="data row6 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_773b5_level0_row7" class="row_heading level0 row7" >12</th>
#       <td id="T_773b5_row7_col0" class="data row7 col0" >False</td>
#       <td id="T_773b5_row7_col1" class="data row7 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of windy - False = 0.811
# <style type="text/css">
# #T_86e40 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_86e40 td {
#   border: 1px solid gray;
# }
# #T_86e40 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_86e40_row0_col0, #T_86e40_row1_col0, #T_86e40_row2_col0, #T_86e40_row3_col0, #T_86e40_row4_col0, #T_86e40_row5_col0 {
#   width: 80px;
# }
# #T_86e40_row0_col1, #T_86e40_row1_col1, #T_86e40_row5_col1 {
#   background-color: pink;
#   width: 80px;
# }
# #T_86e40_row2_col1, #T_86e40_row3_col1, #T_86e40_row4_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# </style>
# <table id="T_86e40" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86e40_level0_col0" class="col_heading level0 col0" >windy</th>
#       <th id="T_86e40_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86e40_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_86e40_row0_col0" class="data row0 col0" >True</td>
#       <td id="T_86e40_row0_col1" class="data row0 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_86e40_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_86e40_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_86e40_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_86e40_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_86e40_row2_col0" class="data row2 col0" >True</td>
#       <td id="T_86e40_row2_col1" class="data row2 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_86e40_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_86e40_row3_col0" class="data row3 col0" >True</td>
#       <td id="T_86e40_row3_col1" class="data row3 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_86e40_level0_row4" class="row_heading level0 row4" >11</th>
#       <td id="T_86e40_row4_col0" class="data row4 col0" >True</td>
#       <td id="T_86e40_row4_col1" class="data row4 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_86e40_level0_row5" class="row_heading level0 row5" >13</th>
#       <td id="T_86e40_row5_col0" class="data row5 col0" >True</td>
#       <td id="T_86e40_row5_col1" class="data row5 col1" >no</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of windy - True = 1.0
# Information Gain for windy = 0.048

# %%
sunny = data[data['outlook'] == 'sunny']
sunny.style.applymap(highlight)\
    .set_properties(subset=data.columns, **{'width': '100px'})\
    .set_table_styles([{'selector': 'th', 'props': [('background-color', 'lightgray'), ('border', '1px solid gray'),
                                                    ('font-weight', 'bold')]},
     {'selector': 'tr:hover', 'props': [('background-color', 'white'), ('border', '1.5px solid black')]}])
# Out:
# <style type="text/css">
# #T_961d6 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_961d6 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_961d6_row0_col0, #T_961d6_row0_col1, #T_961d6_row0_col2, #T_961d6_row0_col3, #T_961d6_row1_col0, #T_961d6_row1_col1, #T_961d6_row1_col2, #T_961d6_row1_col3, #T_961d6_row2_col0, #T_961d6_row2_col1, #T_961d6_row2_col2, #T_961d6_row2_col3, #T_961d6_row3_col0, #T_961d6_row3_col1, #T_961d6_row3_col2, #T_961d6_row3_col3, #T_961d6_row4_col0, #T_961d6_row4_col1, #T_961d6_row4_col2, #T_961d6_row4_col3 {
#   width: 100px;
# }
# #T_961d6_row0_col4, #T_961d6_row1_col4, #T_961d6_row2_col4 {
#   background-color: pink;
#   width: 100px;
# }
# #T_961d6_row3_col4, #T_961d6_row4_col4 {
#   background-color: lightgreen;
#   width: 100px;
# }
# </style>
# <table id="T_961d6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_961d6_level0_col0" class="col_heading level0 col0" >outlook</th>
#       <th id="T_961d6_level0_col1" class="col_heading level0 col1" >temp</th>
#       <th id="T_961d6_level0_col2" class="col_heading level0 col2" >humidity</th>
#       <th id="T_961d6_level0_col3" class="col_heading level0 col3" >windy</th>
#       <th id="T_961d6_level0_col4" class="col_heading level0 col4" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_961d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_961d6_row0_col0" class="data row0 col0" >sunny</td>
#       <td id="T_961d6_row0_col1" class="data row0 col1" >hot</td>
#       <td id="T_961d6_row0_col2" class="data row0 col2" >high</td>
#       <td id="T_961d6_row0_col3" class="data row0 col3" >False</td>
#       <td id="T_961d6_row0_col4" class="data row0 col4" >no</td>
#     </tr>
#     <tr>
#       <th id="T_961d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_961d6_row1_col0" class="data row1 col0" >sunny</td>
#       <td id="T_961d6_row1_col1" class="data row1 col1" >hot</td>
#       <td id="T_961d6_row1_col2" class="data row1 col2" >high</td>
#       <td id="T_961d6_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_961d6_row1_col4" class="data row1 col4" >no</td>
#     </tr>
#     <tr>
#       <th id="T_961d6_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_961d6_row2_col0" class="data row2 col0" >sunny</td>
#       <td id="T_961d6_row2_col1" class="data row2 col1" >mild</td>
#       <td id="T_961d6_row2_col2" class="data row2 col2" >high</td>
#       <td id="T_961d6_row2_col3" class="data row2 col3" >False</td>
#       <td id="T_961d6_row2_col4" class="data row2 col4" >no</td>
#     </tr>
#     <tr>
#       <th id="T_961d6_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_961d6_row3_col0" class="data row3 col0" >sunny</td>
#       <td id="T_961d6_row3_col1" class="data row3 col1" >cool</td>
#       <td id="T_961d6_row3_col2" class="data row3 col2" >normal</td>
#       <td id="T_961d6_row3_col3" class="data row3 col3" >False</td>
#       <td id="T_961d6_row3_col4" class="data row3 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_961d6_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_961d6_row4_col0" class="data row4 col0" >sunny</td>
#       <td id="T_961d6_row4_col1" class="data row4 col1" >mild</td>
#       <td id="T_961d6_row4_col2" class="data row4 col2" >normal</td>
#       <td id="T_961d6_row4_col3" class="data row4 col3" >True</td>
#       <td id="T_961d6_row4_col4" class="data row4 col4" >yes</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(f'Entropy of the Sunny dataset: {find_entropy(sunny.play)}')
# Out:
# Entropy of the Sunny dataset: 0.971

# %%
entropy_and_infogain(sunny, 'temp')
# Out:
# <style type="text/css">
# #T_ff6ad th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_ff6ad td {
#   border: 1px solid gray;
# }
# #T_ff6ad tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_ff6ad_row0_col0, #T_ff6ad_row1_col0 {
#   width: 80px;
# }
# #T_ff6ad_row0_col1, #T_ff6ad_row1_col1 {
#   background-color: pink;
#   width: 80px;
# }
# </style>
# <table id="T_ff6ad" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff6ad_level0_col0" class="col_heading level0 col0" >temp</th>
#       <th id="T_ff6ad_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff6ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff6ad_row0_col0" class="data row0 col0" >hot</td>
#       <td id="T_ff6ad_row0_col1" class="data row0 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_ff6ad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff6ad_row1_col0" class="data row1 col0" >hot</td>
#       <td id="T_ff6ad_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of temp - hot = 0.0
# <style type="text/css">
# #T_6ab10 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_6ab10 td {
#   border: 1px solid gray;
# }
# #T_6ab10 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_6ab10_row0_col0, #T_6ab10_row1_col0 {
#   width: 80px;
# }
# #T_6ab10_row0_col1 {
#   background-color: pink;
#   width: 80px;
# }
# #T_6ab10_row1_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# </style>
# <table id="T_6ab10" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ab10_level0_col0" class="col_heading level0 col0" >temp</th>
#       <th id="T_6ab10_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ab10_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_6ab10_row0_col0" class="data row0 col0" >mild</td>
#       <td id="T_6ab10_row0_col1" class="data row0 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_6ab10_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_6ab10_row1_col0" class="data row1 col0" >mild</td>
#       <td id="T_6ab10_row1_col1" class="data row1 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of temp - mild = 1.0
# <style type="text/css">
# #T_fab3a th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_fab3a td {
#   border: 1px solid gray;
# }
# #T_fab3a tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_fab3a_row0_col0 {
#   width: 80px;
# }
# #T_fab3a_row0_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# </style>
# <table id="T_fab3a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fab3a_level0_col0" class="col_heading level0 col0" >temp</th>
#       <th id="T_fab3a_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fab3a_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_fab3a_row0_col0" class="data row0 col0" >cool</td>
#       <td id="T_fab3a_row0_col1" class="data row0 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of temp - cool = 0.0
# Information Gain for temp = 0.571

# %%
entropy_and_infogain(sunny, 'humidity')
# Out:
# <style type="text/css">
# #T_52905 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_52905 td {
#   border: 1px solid gray;
# }
# #T_52905 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_52905_row0_col0, #T_52905_row1_col0, #T_52905_row2_col0 {
#   width: 80px;
# }
# #T_52905_row0_col1, #T_52905_row1_col1, #T_52905_row2_col1 {
#   background-color: pink;
#   width: 80px;
# }
# </style>
# <table id="T_52905" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52905_level0_col0" class="col_heading level0 col0" >humidity</th>
#       <th id="T_52905_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52905_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52905_row0_col0" class="data row0 col0" >high</td>
#       <td id="T_52905_row0_col1" class="data row0 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_52905_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_52905_row1_col0" class="data row1 col0" >high</td>
#       <td id="T_52905_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_52905_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_52905_row2_col0" class="data row2 col0" >high</td>
#       <td id="T_52905_row2_col1" class="data row2 col1" >no</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of humidity - high = 0.0
# <style type="text/css">
# #T_dc9f3 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_dc9f3 td {
#   border: 1px solid gray;
# }
# #T_dc9f3 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_dc9f3_row0_col0, #T_dc9f3_row1_col0 {
#   width: 80px;
# }
# #T_dc9f3_row0_col1, #T_dc9f3_row1_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# </style>
# <table id="T_dc9f3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc9f3_level0_col0" class="col_heading level0 col0" >humidity</th>
#       <th id="T_dc9f3_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc9f3_level0_row0" class="row_heading level0 row0" >8</th>
#       <td id="T_dc9f3_row0_col0" class="data row0 col0" >normal</td>
#       <td id="T_dc9f3_row0_col1" class="data row0 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_dc9f3_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_dc9f3_row1_col0" class="data row1 col0" >normal</td>
#       <td id="T_dc9f3_row1_col1" class="data row1 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of humidity - normal = 0.0
# Information Gain for humidity = 0.971

# %%
entropy_and_infogain(sunny, 'windy')
# Out:
# <style type="text/css">
# #T_fe740 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_fe740 td {
#   border: 1px solid gray;
# }
# #T_fe740 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_fe740_row0_col0, #T_fe740_row1_col0, #T_fe740_row2_col0 {
#   width: 80px;
# }
# #T_fe740_row0_col1, #T_fe740_row1_col1 {
#   background-color: pink;
#   width: 80px;
# }
# #T_fe740_row2_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# </style>
# <table id="T_fe740" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe740_level0_col0" class="col_heading level0 col0" >windy</th>
#       <th id="T_fe740_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe740_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe740_row0_col0" class="data row0 col0" >False</td>
#       <td id="T_fe740_row0_col1" class="data row0 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_fe740_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_fe740_row1_col0" class="data row1 col0" >False</td>
#       <td id="T_fe740_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_fe740_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_fe740_row2_col0" class="data row2 col0" >False</td>
#       <td id="T_fe740_row2_col1" class="data row2 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of windy - False = 0.918
# <style type="text/css">
# #T_4a391 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_4a391 td {
#   border: 1px solid gray;
# }
# #T_4a391 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_4a391_row0_col0, #T_4a391_row1_col0 {
#   width: 80px;
# }
# #T_4a391_row0_col1 {
#   background-color: pink;
#   width: 80px;
# }
# #T_4a391_row1_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# </style>
# <table id="T_4a391" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a391_level0_col0" class="col_heading level0 col0" >windy</th>
#       <th id="T_4a391_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a391_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4a391_row0_col0" class="data row0 col0" >True</td>
#       <td id="T_4a391_row0_col1" class="data row0 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_4a391_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_4a391_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_4a391_row1_col1" class="data row1 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of windy - True = 1.0
# Information Gain for windy = 0.02

# %%
rainy = data[data['outlook'] == 'rainy']
rainy.style.applymap(highlight)\
    .set_properties(subset=data.columns, **{'width': '100px'})\
    .set_table_styles([{'selector': 'th', 'props': [('background-color', 'lightgray'), ('border', '1px solid gray'),
                                                    ('font-weight', 'bold')]},
     {'selector': 'tr:hover', 'props': [('background-color', 'white'), ('border', '1.5px solid black')]}])
# Out:
# <style type="text/css">
# #T_7c8cb th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_7c8cb tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_7c8cb_row0_col0, #T_7c8cb_row0_col1, #T_7c8cb_row0_col2, #T_7c8cb_row0_col3, #T_7c8cb_row1_col0, #T_7c8cb_row1_col1, #T_7c8cb_row1_col2, #T_7c8cb_row1_col3, #T_7c8cb_row2_col0, #T_7c8cb_row2_col1, #T_7c8cb_row2_col2, #T_7c8cb_row2_col3, #T_7c8cb_row3_col0, #T_7c8cb_row3_col1, #T_7c8cb_row3_col2, #T_7c8cb_row3_col3, #T_7c8cb_row4_col0, #T_7c8cb_row4_col1, #T_7c8cb_row4_col2, #T_7c8cb_row4_col3 {
#   width: 100px;
# }
# #T_7c8cb_row0_col4, #T_7c8cb_row1_col4, #T_7c8cb_row3_col4 {
#   background-color: lightgreen;
#   width: 100px;
# }
# #T_7c8cb_row2_col4, #T_7c8cb_row4_col4 {
#   background-color: pink;
#   width: 100px;
# }
# </style>
# <table id="T_7c8cb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c8cb_level0_col0" class="col_heading level0 col0" >outlook</th>
#       <th id="T_7c8cb_level0_col1" class="col_heading level0 col1" >temp</th>
#       <th id="T_7c8cb_level0_col2" class="col_heading level0 col2" >humidity</th>
#       <th id="T_7c8cb_level0_col3" class="col_heading level0 col3" >windy</th>
#       <th id="T_7c8cb_level0_col4" class="col_heading level0 col4" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c8cb_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_7c8cb_row0_col0" class="data row0 col0" >rainy</td>
#       <td id="T_7c8cb_row0_col1" class="data row0 col1" >mild</td>
#       <td id="T_7c8cb_row0_col2" class="data row0 col2" >high</td>
#       <td id="T_7c8cb_row0_col3" class="data row0 col3" >False</td>
#       <td id="T_7c8cb_row0_col4" class="data row0 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cb_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_7c8cb_row1_col0" class="data row1 col0" >rainy</td>
#       <td id="T_7c8cb_row1_col1" class="data row1 col1" >cool</td>
#       <td id="T_7c8cb_row1_col2" class="data row1 col2" >normal</td>
#       <td id="T_7c8cb_row1_col3" class="data row1 col3" >False</td>
#       <td id="T_7c8cb_row1_col4" class="data row1 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cb_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_7c8cb_row2_col0" class="data row2 col0" >rainy</td>
#       <td id="T_7c8cb_row2_col1" class="data row2 col1" >cool</td>
#       <td id="T_7c8cb_row2_col2" class="data row2 col2" >normal</td>
#       <td id="T_7c8cb_row2_col3" class="data row2 col3" >True</td>
#       <td id="T_7c8cb_row2_col4" class="data row2 col4" >no</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cb_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_7c8cb_row3_col0" class="data row3 col0" >rainy</td>
#       <td id="T_7c8cb_row3_col1" class="data row3 col1" >mild</td>
#       <td id="T_7c8cb_row3_col2" class="data row3 col2" >normal</td>
#       <td id="T_7c8cb_row3_col3" class="data row3 col3" >False</td>
#       <td id="T_7c8cb_row3_col4" class="data row3 col4" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cb_level0_row4" class="row_heading level0 row4" >13</th>
#       <td id="T_7c8cb_row4_col0" class="data row4 col0" >rainy</td>
#       <td id="T_7c8cb_row4_col1" class="data row4 col1" >mild</td>
#       <td id="T_7c8cb_row4_col2" class="data row4 col2" >high</td>
#       <td id="T_7c8cb_row4_col3" class="data row4 col3" >True</td>
#       <td id="T_7c8cb_row4_col4" class="data row4 col4" >no</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(f'Entropy of the Rainy dataset: {find_entropy(rainy.play)}')
# Out:
# Entropy of the Rainy dataset: 0.971

# %%
entropy_and_infogain(rainy, 'temp')
# Out:
# <style type="text/css">
# #T_e6cc4 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_e6cc4 td {
#   border: 1px solid gray;
# }
# #T_e6cc4 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_e6cc4_row0_col0, #T_e6cc4_row1_col0, #T_e6cc4_row2_col0 {
#   width: 80px;
# }
# #T_e6cc4_row0_col1, #T_e6cc4_row1_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# #T_e6cc4_row2_col1 {
#   background-color: pink;
#   width: 80px;
# }
# </style>
# <table id="T_e6cc4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6cc4_level0_col0" class="col_heading level0 col0" >temp</th>
#       <th id="T_e6cc4_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6cc4_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_e6cc4_row0_col0" class="data row0 col0" >mild</td>
#       <td id="T_e6cc4_row0_col1" class="data row0 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_e6cc4_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_e6cc4_row1_col0" class="data row1 col0" >mild</td>
#       <td id="T_e6cc4_row1_col1" class="data row1 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_e6cc4_level0_row2" class="row_heading level0 row2" >13</th>
#       <td id="T_e6cc4_row2_col0" class="data row2 col0" >mild</td>
#       <td id="T_e6cc4_row2_col1" class="data row2 col1" >no</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of temp - mild = 0.918
# <style type="text/css">
# #T_c491d th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_c491d td {
#   border: 1px solid gray;
# }
# #T_c491d tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_c491d_row0_col0, #T_c491d_row1_col0 {
#   width: 80px;
# }
# #T_c491d_row0_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# #T_c491d_row1_col1 {
#   background-color: pink;
#   width: 80px;
# }
# </style>
# <table id="T_c491d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c491d_level0_col0" class="col_heading level0 col0" >temp</th>
#       <th id="T_c491d_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c491d_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_c491d_row0_col0" class="data row0 col0" >cool</td>
#       <td id="T_c491d_row0_col1" class="data row0 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_c491d_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_c491d_row1_col0" class="data row1 col0" >cool</td>
#       <td id="T_c491d_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of temp - cool = 1.0
# Information Gain for temp = 0.02

# %%
entropy_and_infogain(rainy, 'humidity')
# Out:
# <style type="text/css">
# #T_deb03 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_deb03 td {
#   border: 1px solid gray;
# }
# #T_deb03 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_deb03_row0_col0, #T_deb03_row1_col0 {
#   width: 80px;
# }
# #T_deb03_row0_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# #T_deb03_row1_col1 {
#   background-color: pink;
#   width: 80px;
# }
# </style>
# <table id="T_deb03" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_deb03_level0_col0" class="col_heading level0 col0" >humidity</th>
#       <th id="T_deb03_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_deb03_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_deb03_row0_col0" class="data row0 col0" >high</td>
#       <td id="T_deb03_row0_col1" class="data row0 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_deb03_level0_row1" class="row_heading level0 row1" >13</th>
#       <td id="T_deb03_row1_col0" class="data row1 col0" >high</td>
#       <td id="T_deb03_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of humidity - high = 1.0
# <style type="text/css">
# #T_013d6 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_013d6 td {
#   border: 1px solid gray;
# }
# #T_013d6 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_013d6_row0_col0, #T_013d6_row1_col0, #T_013d6_row2_col0 {
#   width: 80px;
# }
# #T_013d6_row0_col1, #T_013d6_row2_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# #T_013d6_row1_col1 {
#   background-color: pink;
#   width: 80px;
# }
# </style>
# <table id="T_013d6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_013d6_level0_col0" class="col_heading level0 col0" >humidity</th>
#       <th id="T_013d6_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_013d6_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_013d6_row0_col0" class="data row0 col0" >normal</td>
#       <td id="T_013d6_row0_col1" class="data row0 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_013d6_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_013d6_row1_col0" class="data row1 col0" >normal</td>
#       <td id="T_013d6_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_013d6_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_013d6_row2_col0" class="data row2 col0" >normal</td>
#       <td id="T_013d6_row2_col1" class="data row2 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of humidity - normal = 0.918
# Information Gain for humidity = 0.02

# %%
entropy_and_infogain(rainy, 'windy')
# Out:
# <style type="text/css">
# #T_3894d th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_3894d td {
#   border: 1px solid gray;
# }
# #T_3894d tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_3894d_row0_col0, #T_3894d_row1_col0, #T_3894d_row2_col0 {
#   width: 80px;
# }
# #T_3894d_row0_col1, #T_3894d_row1_col1, #T_3894d_row2_col1 {
#   background-color: lightgreen;
#   width: 80px;
# }
# </style>
# <table id="T_3894d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3894d_level0_col0" class="col_heading level0 col0" >windy</th>
#       <th id="T_3894d_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3894d_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_3894d_row0_col0" class="data row0 col0" >False</td>
#       <td id="T_3894d_row0_col1" class="data row0 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_3894d_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_3894d_row1_col0" class="data row1 col0" >False</td>
#       <td id="T_3894d_row1_col1" class="data row1 col1" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_3894d_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_3894d_row2_col0" class="data row2 col0" >False</td>
#       <td id="T_3894d_row2_col1" class="data row2 col1" >yes</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of windy - False = 0.0
# <style type="text/css">
# #T_26e07 th {
#   background-color: lightgray;
#   border: 1px solid gray;
#   font-weight: bold;
# }
# #T_26e07 td {
#   border: 1px solid gray;
# }
# #T_26e07 tr:hover {
#   background-color: white;
#   border: 1.5px solid black;
# }
# #T_26e07_row0_col0, #T_26e07_row1_col0 {
#   width: 80px;
# }
# #T_26e07_row0_col1, #T_26e07_row1_col1 {
#   background-color: pink;
#   width: 80px;
# }
# </style>
# <table id="T_26e07" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26e07_level0_col0" class="col_heading level0 col0" >windy</th>
#       <th id="T_26e07_level0_col1" class="col_heading level0 col1" >play</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26e07_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_26e07_row0_col0" class="data row0 col0" >True</td>
#       <td id="T_26e07_row0_col1" class="data row0 col1" >no</td>
#     </tr>
#     <tr>
#       <th id="T_26e07_level0_row1" class="row_heading level0 row1" >13</th>
#       <td id="T_26e07_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_26e07_row1_col1" class="data row1 col1" >no</td>
#     </tr>
#   </tbody>
# </table>
# Entropy of windy - True = 0.0
# Information Gain for windy = 0.971
